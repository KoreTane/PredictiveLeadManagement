# %% [markdown]
# <a href="https://colab.research.google.com/github/KoreTane/PredictiveLeadManagement/blob/main/CashFlow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('relatorio.xlsx')

# %%
df.head(100)
# Out:
#    Fluxo de caixa                                                                       Exportar              Imprimir  \
# 0                           Categorias de lançamentos
# 1                                            Receitas
# 2                                     Venda no boleto
# 3                                         Mensalidade
# 4                         24006 - Alice Galvão Di ...
# ..                                                ...
# 95                                                NaN
# 96                        24017 - Maria Clara Lei ...
# 97                                                NaN
# 98                        24005 - Luna do Prado C ...
# 99                                                NaN
#
#     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0          NaN     01/Abr     02/Abr     03/Abr
# 1          NaN   26642.01          0          0
# 2          NaN    1990.85          0          0
# 3          NaN    1990.85          0          0
# ...

# %%
df['Total'] = df['Unnamed: 2'] + df['Unnamed: 3'] + df['Unnamed: 4']
df.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], axis=1, inplace=True)
df = df.drop(df.index[0])
df.rename(columns={df.columns[0]: 'Lançamentos'}, inplace=True)
df[['Matrícula', 'Lançamentos']] = df['Lançamentos'].str.split('- ', n=1, expand=True)
df = df[['Matrícula', 'Lançamentos', 'Total']]

# %%
df.iloc[3:7]
# Out:
#   Matrícula          Lançamentos   Total
# 4    24006   Alice Galvão Di ...  419.75
# 5    23088   Maria Rita Barr ...  407.45
# 6    23098   Olivia Clasen C ...   377.5
# 7    23016   Mariana de Fati ...   418.7
