# %% [markdown]
# <a href="https://colab.research.google.com/github/KoreTane/PredictiveLeadManagement/blob/main/Fluxo_de_caixa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install pdfminer
#!pip install python-docx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 1.8 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('relatorio.xlsx')

# %%
df.head(100)
# Out:
#    Fluxo de caixa                                                                       Exportar              Imprimir  \
# 0                           Categorias de lançamentos
# 1                                            Receitas
# 2                                     Venda no boleto
# 3                                         Mensalidade
# 4                         24006 - Alice Galvão Di ...
# ..                                                ...
# 95                                                NaN
# 96                        24017 - Maria Clara Lei ...
# 97                                                NaN
# 98                        24005 - Luna do Prado C ...
# 99                                                NaN
#
#     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0          NaN     01/Abr     02/Abr     03/Abr
# 1          NaN   26642.01          0          0
# 2          NaN    1990.85          0          0
# 3          NaN    1990.85          0          0
# ...
